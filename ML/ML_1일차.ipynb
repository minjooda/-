# %%
#Machine Learning
#지도학습

# %%
import sklearn
sklearn.__version__
# Out:
# '0.21.3'

# %%
from sklearn.svm  import LinearSVC
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
#1.목표정하기 ---- AND 연산 
#2. 훈련용 입력 data, label (라벨링되어있음 )
train_data = [[0,0],[0,1],[1,0],[1,1]]
train_label = [0,0,0,1]

#3. test용 입력 data, label (라벨링되어있음 )
test_data = [[0,1],[1,0],[1,1]]
test_label = [0,0,1]

#4.알고리즘 선택 (모델만들기)
#https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
model = LinearSVC()

#5.훈련 
model.fit(train_data, train_label)

#6.test 
pred_label = model.predict(test_data)
print("예측결과:", pred_label)
print("정확도 측정:", accuracy_score(test_label, pred_label))
# Out:
# 에측결과: [0 0 1]
# 정확도 측정: 1.0

# %%
print(test_label == pred_label)

import numpy as np

np.sum(test_label != pred_label)
# Out:
# [ True  True  True]
# 0

# %%
from sklearn.svm  import LinearSVC
from sklearn.metrics import accuracy_score

#1.목표정하기 ---- AND 연산 
#2. 훈련용 입력 data, label (라벨링되어있음 )
train_data = [[0,0],[0,1],[1,0],[1,1]]
train_label = [0,1,1,1]

#3. test용 입력 data, label (라벨링되어있음 )
test_data = [[0,0],[0,1],[1,0],[1,1]]
test_label = [0,1,1,1]

#4.알고리즘 선택 (모델만들기)
#https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
model = LinearSVC()

#5.훈련 
model.fit(train_data, train_label)

#6.test 
pred_label = model.predict(test_data)
print("예측결과:", pred_label)
print("정확도 측정:", accuracy_score(test_label, pred_label))
# Out:
# 예측결과: [0 1 1 1]
# 정확도 측정: 1.0

# %%
from sklearn.svm  import LinearSVC
from sklearn.metrics import accuracy_score

#1.목표정하기 ---- XOR 연산 
#2. 훈련용 입력 data, label (라벨링되어있음 )
train_data = [[0,0],[0,1],[1,0],[1,1]]
train_label = [0,1,1,0]

#3. test용 입력 data, label (라벨링되어있음 )
test_data = [[0,0],[0,1],[1,0],[1,1]]
test_label = [0,1,1,0]

#4.알고리즘 선택 (모델만들기)
#https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
#model = LinearSVC()
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)

#5.훈련 
model.fit(train_data, train_label)

#6.test 
pred_label = model.predict(test_data)
print("예측결과:", pred_label)
print("정확도 측정:", accuracy_score(test_label, pred_label))
# Out:
# 예측결과: [0 1 1 0]
# 정확도 측정: 1.0

# %%
from sklearn import datasets

iris = datasets.load_iris()

iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
x = iris.data
y = iris.target
iris.feature_names

import pandas as pd
df = pd.DataFrame(x, columns=iris.feature_names)
df["Name"] = y
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Name
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
import urllib.request as req

url="https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv"

req.urlretrieve(url, "iris.csv")
print("저장됨.........")

iris_data = pd.read_csv("iris.csv")
iris_data.head()
# Out:
# 저장됨.........
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
import warnings
warnings.filterwarnings("ignore")
#label 
y = iris_data.loc[: , "Name"]

#data
#x = iris_data.loc[: , ["SepalLength","SepalWidth","PetalLength","PetalWidth"]]
#x = iris_data.loc[:, iris_data.columns[0:-1]]
x = iris_data.drop("Name", axis=1)

x2 = [[5.1,3.0, 1.5, 0.2]]
model = LinearSVC()
model.fit(x, y)
pre_label = model.predict(x2)
print(pre_label)
# Out:
# ['Iris-setosa']

# %%
y = iris_data.loc[: , "Name"]

#data
#x = iris_data.loc[: , ["SepalLength","SepalWidth","PetalLength","PetalWidth"]]
#x = iris_data.loc[:, iris_data.columns[0:-1]]
x = iris_data.drop("Name", axis=1)

#model = LinearSVC()
model = KNeighborsClassifier(n_neighbors=1)

from sklearn.model_selection import train_test_split
#학습데이터와 테스트데이터로 나눈다. 
train_data,test_data,train_label,test_label =  \
            train_test_split(x, y, test_size=0.2, \
                  train_size=0.8, shuffle=True,   \
                 random_state=121) 
#학습 
model.fit(train_data, train_label)
pre_label = model.predict(test_data)
print("정확도:", accuracy_score(test_label, pre_label))
# Out:
# 정확도: 0.9666666666666667

# %%
y = iris_data.loc[: , "Name"]

#data
#x = iris_data.loc[: , ["SepalLength","SepalWidth","PetalLength","PetalWidth"]]
#x = iris_data.loc[:, iris_data.columns[0:-1]]
x = iris_data.drop("Name", axis=1)

#model = LinearSVC()
#model = KNeighborsClassifier(n_neighbors=1)

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

#SVC, KNN, 결정트리 
model = DecisionTreeClassifier(random_state=153)

from sklearn.model_selection import train_test_split
#학습데이터와 테스트데이터로 나눈다. 
train_data,test_data,train_label,test_label =  \
            train_test_split(x, y, test_size=0.2, \
                  train_size=0.8, shuffle=True,   \
                 random_state=121) 
#학습 
model.fit(train_data, train_label)
pre_label = model.predict(test_data)
print("정확도:", accuracy_score(test_label, pre_label))
#impurity=True 불순도....지니지수 보여주기 
export_graphviz(model, out_file="tree.dot",
                feature_names=iris_data.columns[0:-1],
                impurity=True, filled=True
               )

with open("tree.dot") as f:
    dot_g = f.read()
graphviz.Source(dot_g)
# Out:
# 정확도: 0.9666666666666667

# %%
y = iris_data.loc[: , "Name"]

#data
#x = iris_data.loc[: , ["SepalLength","SepalWidth","PetalLength","PetalWidth"]]
#x = iris_data.loc[:, iris_data.columns[0:-1]]
x = iris_data.drop("Name", axis=1)

#model = LinearSVC()
#model = KNeighborsClassifier(n_neighbors=1)

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

#SVC, KNN, 결정트리 
#model = DecisionTreeClassifier(max_depth=4, random_state=153)
#model = DecisionTreeClassifier(min_samples_split=4, random_state=153)
model = DecisionTreeClassifier(min_samples_leaf=4, random_state=153)

from sklearn.model_selection import train_test_split
#학습데이터와 테스트데이터로 나눈다. 
train_data,test_data,train_label,test_label =  \
            train_test_split(x, y, test_size=0.2, \
                  train_size=0.8, shuffle=True,   \
                 random_state=121) 
#학습 
model.fit(train_data, train_label)
pre_label = model.predict(test_data)
print("정확도:", accuracy_score(test_label, pre_label))
#impurity=True 불순도....지니지수 보여주기 
export_graphviz(model, out_file="tree.dot",
                feature_names=iris_data.columns[0:-1],
                impurity=True, filled=True
               )

with open("tree.dot") as f:
    dot_g = f.read()
graphviz.Source(dot_g)
# Out:
# 정확도: 0.9666666666666667
